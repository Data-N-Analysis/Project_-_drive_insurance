# %% [markdown]
# <a href="https://colab.research.google.com/github/Sminjoo/Project_ORI-Team_drive_insurance/blob/main/EDA/SMJ_EDA_%EB%B3%B4%ED%97%98%EA%B5%90%EC%B0%A8%ED%8C%90%EB%A7%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import pandas as pd
train = pd.read_csv('/content/drive/MyDrive/보험대회/train.csv')
train.head(5)
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
test = pd.read_csv('/content/drive/MyDrive/보험대회/test.csv')
submission = pd.read_csv('/content/drive/MyDrive/보험대회/sample_submission.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
train.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
sns.countplot(data= train, x= 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data= test, x= 'Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df = train.Gender.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.displot(train['Age'])

# %%
fig, ax = plt.subplots()
sns.kdeplot(train['Age'],ax=ax)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(test['Age'])

# %%
df = train.Driving_License.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df = test.Driving_License.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.displot(train['Region_Code'])

# %%
sns.displot(test['Region_Code'])

# %%
df = train.Region_Code.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df = train.Previously_Insured	.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df = test.Previously_Insured	.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data= train, x= 'Vehicle_Age')
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>

# %%
df = train.Vehicle_Age.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df = train.Vehicle_Damage.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data=train, y='Annual_Premium')
plt.show()

# %%
sns.violinplot(data=train, y='Annual_Premium')
plt.show()

# %%
sns.countplot(data= train, x= 'Policy_Sales_Channel')
# Out:
# <Axes: xlabel='Policy_Sales_Channel', ylabel='count'>

# %%
df = train.Policy_Sales_Channel.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(train['Vintage'],ax=ax)
# Out:
# <Axes: xlabel='Vintage', ylabel='Density'>

# %%
sns.displot(test['Vintage'])

# %%
sns.boxplot(data=train, y='Vintage')
plt.show()

# %%
df = train.Response.value_counts()
df.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train.describe().astype('int64')
# Out:
#              id       Age  Driving_License  Region_Code  Previously_Insured  \
# count  11504798  11504798         11504798     11504798            11504798
# mean    5752398        38                0           26                   0
# std     3321149        14                0           12                   0
# min           0        20                0            0                   0
# 25%     2876199        24                1           15                   0
# 50%     5752398        36                1           28                   0
# 75%     8628597        49                1           35                   1
# max    11504797        85                1           52                   1
#
#        Annual_Premium  Policy_Sales_Channel   Vintage  Response
# count        11504798              11504798  11504798  11504798
# mean            30461                   112       163         0
# std             16454                    54        79         0
# ...

# %%
sns.countplot(data=train, hue='Response', x='Gender')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
train[['Gender','Response']].groupby('Gender').mean()
# Out:
#         Response
# Gender
# Female  0.103297
# Male    0.139688

# %%
sns.countplot(data=train, hue='Response', x='Driving_License')
# Out:
# <Axes: xlabel='Driving_License', ylabel='count'>

# %%
train[['Driving_License','Response']].groupby('Driving_License').mean()
# Out:
#                  Response
# Driving_License
# 0                0.055148
# 1                0.123132

# %%
sns.countplot(data=train, hue='Response', x='Previously_Insured')
# Out:
# <Axes: xlabel='Previously_Insured', ylabel='count'>

# %%
train[['Previously_Insured','Response']].groupby('Previously_Insured').mean()
# Out:
#                     Response
# Previously_Insured
# 0                   0.228493
# 1                   0.000638

# %%
sns.countplot(data=train, hue='Response', x='Vehicle_Age')
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>

# %%
train[['Vehicle_Age','Response']].groupby('Vehicle_Age').mean()
# Out:
#              Response
# Vehicle_Age
# 1-2 Year     0.177725
# < 1 Year     0.041404
# > 2 Years    0.299049

# %%
sns.countplot(data=train, hue='Response', x='Vehicle_Damage')
# Out:
# <Axes: xlabel='Vehicle_Damage', ylabel='count'>

# %%
train[['Vehicle_Damage','Response']].groupby('Vehicle_Damage').mean()
# Out:
#                 Response
# Vehicle_Damage
# No              0.004198
# Yes             0.240530

# %%
fig, ax = plt.subplots()
sns.kdeplot(train[train['Response']==0]['Age'],ax=ax)
sns.kdeplot(train[train['Response']==1]['Age'],ax=ax)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(train[train['Response']==0]['Region_Code'],ax=ax)
sns.kdeplot(train[train['Response']==1]['Region_Code'],ax=ax)
# Out:
# <Axes: xlabel='Region_Code', ylabel='Density'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(train[train['Response']==0]['Annual_Premium'],ax=ax)
sns.kdeplot(train[train['Response']==1]['Annual_Premium'],ax=ax)
# Out:
# <Axes: xlabel='Annual_Premium', ylabel='Density'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(train[train['Response']==0]['Policy_Sales_Channel'],ax=ax)
sns.kdeplot(train[train['Response']==1]['Policy_Sales_Channel'],ax=ax)
# Out:
# <Axes: xlabel='Policy_Sales_Channel', ylabel='Density'>

# %%
fig, ax = plt.subplots()
sns.kdeplot(train[train['Response']==0]['Vintage'],ax=ax)
sns.kdeplot(train[train['Response']==1]['Vintage'],ax=ax)
# Out:
# <Axes: xlabel='Vintage', ylabel='Density'>

# %%
sns.countplot(data=train, hue='Previously_Insured', x='Vehicle_Age')
# Out:
# <Axes: xlabel='Vehicle_Age', ylabel='count'>
