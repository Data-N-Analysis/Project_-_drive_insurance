# %% [markdown]
# <a href="https://colab.research.google.com/github/ByungHyunPark57/Project_ORI-Team_drive_insurance/blob/main/preprocessing/%EB%B3%B4%ED%97%98_%EA%B5%90%EC%B0%A8%ED%8C%90%EB%A7%A42.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train1 = pd.read_csv("/content/drive/MyDrive/보험 판매예측 데이터 파일/train.csv")
test1 = pd.read_csv("/content/drive/MyDrive/보험 판매예측 데이터 파일/test.csv")
submission = pd.read_csv("/content/drive/MyDrive/보험 판매예측 데이터 파일/sample_submission.csv")

# %%
train2 = pd.read_csv("/content/drive/MyDrive/train2.csv/train.csv")
test2 = pd.read_csv("/content/drive/MyDrive/test2.csv/test.csv")

# %%
train = pd.concat([train1, train2])

# %%
train1
# Out:
#                 id  Gender  Age  Driving_License  Region_Code  \
# 0                0    Male   21                1         35.0
# 1                1    Male   43                1         28.0
# 2                2  Female   25                1         14.0
# 3                3  Female   35                1          1.0
# 4                4  Female   36                1         15.0
# ...            ...     ...  ...              ...          ...
# 11504793  11504793    Male   48                1          6.0
# 11504794  11504794  Female   26                1         36.0
# 11504795  11504795  Female   29                1         32.0
# 11504796  11504796  Female   51                1         28.0
# 11504797  11504797    Male   25                1         28.0
#
#           Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  \
# 0                          0    1-2 Year            Yes         65101.0
# 1                          0   > 2 Years            Yes         58911.0
# ...

# %%
train2
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1    Male   44                1         28.0                   0
# 1            2    Male   76                1          3.0                   0
# 2            3    Male   47                1         28.0                   0
# 3            4    Male   21                1         11.0                   1
# 4            5  Female   29                1         41.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %%
train
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            0    Male   21                1         35.0                   0
# 1            1    Male   43                1         28.0                   0
# 2            2  Female   25                1         14.0                   1
# 3            3  Female   35                1          1.0                   0
# 4            4  Female   36                1         15.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 381104  381105    Male   74                1         26.0                   1
# 381105  381106    Male   30                1         37.0                   1
# 381106  381107    Male   21                1         30.0                   1
# 381107  381108  Female   68                1         14.0                   0
# 381108  381109    Male   46                1         29.0                   0
#
# ...

# %% [markdown]
# id변수 삭제

# %%
train = train.drop(columns=['id'])

# %% [markdown]
# 성별, 손상여부, 연식 숫자 인코딩

# %%
train['Gender']= train['Gender'].map({'Male':1,'Female':0})

# %%
train['Vehicle_Damage']= train['Vehicle_Damage'].map({'Yes':1,'No':0})

# %%
train['Vehicle_Age'].unique()
# Out:
# array(['1-2 Year', '> 2 Years', '< 1 Year'], dtype=object)

# %%
train['Vehicle_Age'] = train['Vehicle_Age'].map({'1-2 Year':1,'> 2 Years':2,'< 1 Year':0})

# %% [markdown]
# test도 똑같이

# %%
test = pd.concat([test1, test2])
test = test.drop(columns=['id'])
test['Gender']= test['Gender'].map({'Male':1,'Female':0})
test['Vehicle_Damage']= test['Vehicle_Damage'].map({'Yes':1,'No':0})
test['Vehicle_Age'].unique()
test['Vehicle_Age'] = test['Vehicle_Age'].map({'1-2 Year':1,'> 2 Years':2,'< 1 Year':0})

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11885907 entries, 0 to 381108
# Data columns (total 11 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Gender                int64
#  1   Age                   int64
#  2   Driving_License       int64
#  3   Region_Code           float64
#  4   Previously_Insured    int64
#  5   Vehicle_Age           int64
#  6   Vehicle_Damage        int64
#  7   Annual_Premium        float64
#  8   Policy_Sales_Channel  float64
#  9   Vintage               int64
#  10  Response              int64
# dtypes: float64(3), int64(8)
# memory usage: 1.1 GB

# %%
train.isnull().sum()
# Out:
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
train.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 381104    False
# 381105    False
# 381106    False
# 381107    False
# 381108    False
# Length: 11885907, dtype: bool

# %%
train.duplicated().sum()
# Out:
# 269

# %%
train.drop_duplicates()
# Out:
#         Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0            1   21                1         35.0                   0
# 1            1   43                1         28.0                   0
# 2            0   25                1         14.0                   1
# 3            0   35                1          1.0                   0
# 4            0   36                1         15.0                   1
# ...        ...  ...              ...          ...                 ...
# 381104       1   74                1         26.0                   1
# 381105       1   30                1         37.0                   1
# 381106       1   21                1         30.0                   1
# 381107       0   68                1         14.0                   0
# 381108       1   46                1         29.0                   0
#
#         Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# ...

# %%
train.duplicated().sum()
# Out:
# 269

# %% [markdown]
# 모든 행이 같은 중복값은 없는 것으로 보임 ↑

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %%
X, Y = train.drop(columns = ['Response']) , train['Response']
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,test_size=0.2, random_state=123)

# %%
X_train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 3303061        1   56                1         28.0                   0
# 11112903       0   23                1         46.0                   1
# 1131931        1   44                1         46.0                   1
# 9275808        1   26                1         26.0                   0
# 8653383        0   24                1         30.0                   1
# ...          ...  ...              ...          ...                 ...
# 1241052        1   47                1          8.0                   0
# 47268          0   24                1         34.0                   0
# 4222334        1   21                1         35.0                   0
# 8666477        0   21                1         46.0                   1
# 4967934        1   24                1          8.0                   1
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# ...

# %%
Y_train
# Out:
# 3303061     0
# 11112903    0
# 1131931     0
# 9275808     0
# 8653383     0
#            ..
# 1241052     0
# 47268       0
# 4222334     0
# 8666477     0
# 4967934     0
# Name: Response, Length: 9508725, dtype: int64

# %%
xgb  = XGBClassifier()
xgb.fit(X_train, Y_train)

Y_pred = xgb.predict(X_test)

xgb.score(X_train, Y_train)
# Out:
# 0.8802430399448927

# %%
from sklearn.metrics import roc_auc_score

xgb_roc_score = roc_auc_score(Y_test, xgb.predict_proba(X_test)[:,1])
print(xgb_roc_score)
# Out:
# 0.8775619368991773

# %% [markdown]
# SMOTE 기법

# %%
from imblearn.over_sampling import BorderlineSMOTE

# Class 불균형 문제 해결
X_train, Y_train = BorderlineSMOTE().fit_resample(X, Y)

# %%
xgb  = XGBClassifier()
xgb.fit(X_train, Y_train)

Y_pred = xgb.predict(X_test)

xgb.score(X_train, Y_train)
# Out:
# 0.8508234925516144

# %%
X_train
# Out:
#           Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0              1   21                1    35.000000                   0
# 1              1   43                1    28.000000                   0
# 2              0   25                1    14.000000                   1
# 3              0   35                1     1.000000                   0
# 4              0   36                1    15.000000                   1
# ...          ...  ...              ...          ...                 ...
# 20848271       0   36                1    22.422599                   0
# 20848272       1   38                1    28.000000                   0
# 20848273       0   44                1    28.000000                   0
# 20848274       0   50                1    28.000000                   0
# 20848275       0   37                1     8.940477                   0
#
#           Vehicle_Age  Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# ...

# %%
Y_train
# Out:
# 0           0
# 1           1
# 2           0
# 3           0
# 4           0
#            ..
# 20848271    1
# 20848272    1
# 20848273    1
# 20848274    1
# 20848275    1
# Name: Response, Length: 20848276, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.bar(Y_train.index, Y_train, color='skyblue')
plt.xlabel('Index')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ○ 대회 목적 : 전년도에 보험회사의 건강보험에 가입한 사람이 그 회사에서 제공하는
# 자동차 보험에도 관심이 있을 것인지

# %% [markdown]
# ○ 변수 의미

# %% [markdown]
# id: 고유 식별 번호

# %% [markdown]
# Gender : 고객 성별

# %% [markdown]
# Age : 고객 나이

# %% [markdown]
# Driving_License : 고객이 운전면허증을 가지고 있는지 여부(1 = 예, 0 = 아니요)

# %% [markdown]
# Region_Code : 고객의 지역을 나타내는 고유 코드
# - 0~52로 총 53개 있는데 주 로 추정됨
# -  미국의 주는 50개인데 푸에르토리코,괌 같은 미국령 지역 보함하면 50개 넘게 있음
# -  숫자로된 고유번호 찾아봐도 안 나옴

# %% [markdown]
# Previously_Insured : 고객이 이미 자동차 보험에 가입했는지 여부(1 = 예, 0 = 아니요).

# %% [markdown]
# Vehicle_Age : 차량의 연식(얼마나 오래된 차량인지)

# %% [markdown]
# Vehicle_Damage : 고객이 과거에 차량 손상을 경험했는지 여부(1 = 예, 0 = 아니요)

# %% [markdown]
# Annual_Premium : 고객이 지불해야 하는 연간 보험료 금액(전체 보험 금액인듯)

# %% [markdown]
# Policy_Sales_Channel : 상담원, 이메일, 전화 통화 등 고객 연락 채널
# - 익명화된 고유 코드

# %% [markdown]
# Vintage : 건강 보험에 가입한지 얼마나 되었는지

# %% [markdown]
# Response : 고객이 보험 가입에 관심이 있는지 여부(1 = 관심 있음, 0 = 관심 없음).

# %%
train = train[train['Driving_License'] != 0]

# %%
X, Y = train.drop(columns = ['Response']) , train['Response']
X_train, X_test, Y_train, Y_test= train_test_split(X, Y,test_size=0.2, random_state=123)

# %%
xgb  = XGBClassifier()
xgb.fit(X_train, Y_train)

Y_pred = xgb.predict(X_test)

xgb.score(X_train, Y_train)
# Out:
# 0.8800663233532177

# %% [markdown]
# 운전면허 없는 행 제거하니까 0.0002 낮아짐

# %% [markdown]
# 나이 20대가 가장 많이 분포, 연식 2년이상이 매우 적음

# %%
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler

# %%
# 'age'가 20세에서 30세 사이인 샘플에 대해 언더샘플링 수행
rus = RandomUnderSampler(sampling_strategy='majority', random_state=42)

# %%
# 'age'가 20세에서 30세 사이인 샘플을 기준으로 언더샘플링 적용
X_resampled, y_resampled = rus.fit_resample(df[(df['age'] >= 20) & (df['age'] <= 30)][[]],
                                            df[(df['age'] >= 20) & (df['age'] <= 30)][])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-83ff4324bc11> in <cell line: 2>()
#       1 # 'age'가 20세에서 30세 사이인 샘플을 기준으로 언더샘플링 적용
# ----> 2 X_resampled, y_resampled = rus.fit_resample(df[(df['age'] >= 20) & (df['age'] <= 30)][['feature1']],
#       3                                             df[(df['age'] >= 20) & (df['age'] <= 30)]['target'])
#
# NameError: name 'df' is not defined

# %%
# 언더샘플링 결과 확인
df_resampled = pd.DataFrame(X_resampled, columns=['feature1', 'age'])
df_resampled['target'] = y_resampled
